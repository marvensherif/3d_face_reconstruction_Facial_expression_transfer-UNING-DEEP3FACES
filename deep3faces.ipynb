# %%
# !git clone https://github.com/sicxu/Deep3DFaceRecon_pytorch.git
# Out:
# Cloning into 'Deep3DFaceRecon_pytorch'...
# remote: Enumerating objects: 215, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 215 (delta 47), reused 32 (delta 32), pack-reused 121 (from 1)
# Receiving objects: 100% (215/215), 32.68 MiB | 20.42 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %%
cd Deep3DFaceRecon_pytorch
# Out:
# /content/Deep3DFaceRecon_pytorch

# %%
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2024-10-26 17:06:58--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 148337011 (141M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 141.46M   158MB/s    in 0.9s
#
# 2024-10-26 17:06:59 (158 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [148337011/148337011]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
# ...

# %%
# Initialize conda
# !conda init bash

# Reload the bash config so conda is recognized
# !source ~/.bashrc
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.12/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==

# %%
# !conda config --add channels defaults
# !conda config --add channels conda-forge
# !conda config --set channel_priority strict

# %%
# !conda env create -f environment.yml
# Out:
# /usr/local/lib/python3.12/argparse.py:2006: FutureWarning: `remote_definition` is deprecated and will be removed in 25.9. Use `conda env create --file=URL` instead.
#   action(self, namespace, argument_values, option_string)
# Channels:
#  - pytorch
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
# ...
# pytorch-1.6.0        | 537.3 MB  | :   0% 0/1 [00:00<?, ?it/s]
# cudatoolkit-10.2.89  | 351.3 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
# mkl-2024.2.2         | 119.2 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
# python-3.6.15        | 38.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# scikit-image-0.16.2  | 25.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# scipy-1.4.1          | 18.9 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# icu-73.2             | 11.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# torchvision-0.7.0    | 11.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# matplotlib-base-3.3. | 6.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %%
# !source activate deep3d_pytorch

# %%
# !git clone https://github.com/NVlabs/nvdiffrast
# Out:
# Cloning into 'nvdiffrast'...
# remote: Enumerating objects: 404, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 404 (delta 90), reused 77 (delta 77), pack-reused 276 (from 1)
# Receiving objects: 100% (404/404), 11.11 MiB | 16.32 MiB/s, done.
# Resolving deltas: 100% (215/215), done.

# %%
cd nvdiffrast
# Out:
# /content/Deep3DFaceRecon_pytorch/nvdiffrast

# %%
# !pip install .
# Out:
# Processing /content/Deep3DFaceRecon_pytorch/nvdiffrast
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 41.0 MB/s eta 0:00:00
# ...
#   Created wheel for nvdiffrast: filename=nvdiffrast-0.3.3-py3-none-any.whl size=139907 sha256=2db0d1e2914879982f6fd2ac55e2d725e1de40d74e88fb6a27dd7f9a5bbb5c16
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m_ej84df/wheels/79/fa/0f/5d02407babfa429ecf9c8e7b242bf63e4d042d232ac9ad5c0e
# Successfully built nvdiffrast
# ...

# %%
cd ..
# Out:
# /content/Deep3DFaceRecon_pytorch

# %%
# !git clone https://github.com/deepinsight/insightface.git
# Out:
# Cloning into 'insightface'...
# remote: Enumerating objects: 11576, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 11576 (delta 43), reused 111 (delta 38), pack-reused 11442 (from 1)
# Receiving objects: 100% (11576/11576), 45.16 MiB | 20.94 MiB/s, done.
# Resolving deltas: 100% (6060/6060), done.

# %%
cp -r ./insightface/recognition/arcface_torch ./models/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/My\ Drive/01_MorphableModel.mat /content/Deep3DFaceRecon_pytorch/BFM

# %%
# !cp /content/drive/My\ Drive/Exp_Pca.bin /content/Deep3DFaceRecon_pytorch/BFM

# %%
# !cp /content/drive/My\ Drive/epoch_20.pth /content/Deep3DFaceRecon_pytorch/checkpoints/model2009

# %%
# !pip install torch torchvision tensorboard scipy scikit-image opencv-python trimesh dominate kornia ninja
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 28.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 60.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 155.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 166.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 31.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 70.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 65.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 65.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 66.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 71.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 175.3 MB/s eta 0:00:00
# ...

# %%
# !apt-get install -y cuda
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-12 cuda-12-6 cuda-cccl-12-6 cuda-command-line-tools-12-6 cuda-compiler-12-6 cuda-crt-12-6
#   cuda-cudart-12-6 cuda-cudart-dev-12-6 cuda-cuobjdump-12-6 cuda-cupti-12-6 cuda-cupti-dev-12-6
#   cuda-cuxxfilt-12-6 cuda-demo-suite-12-6 cuda-documentation-12-6 cuda-driver-dev-12-6
#   cuda-gdb-12-6 cuda-libraries-12-6 cuda-libraries-dev-12-6 cuda-nsight-12-6
#   cuda-nsight-compute-12-6 cuda-nsight-systems-12-6 cuda-nvcc-12-6 cuda-nvdisasm-12-6
#   cuda-nvml-dev-12-6 cuda-nvprof-12-6 cuda-nvprune-12-6 cuda-nvrtc-12-6 cuda-nvrtc-dev-12-6
#   cuda-nvtx-12-6 cuda-nvvm-12-6 cuda-nvvp-12-6 cuda-opencl-12-6 cuda-opencl-dev-12-6
#   cuda-profiler-api-12-6 cuda-runtime-12-6 cuda-sanitizer-12-6 cuda-toolkit-12-6
#   cuda-toolkit-12-6-config-common cuda-tools-12-6 cuda-visual-tools-12-6 dctrl-tools default-jre
# ...

# %%
# !apt-get update
# !apt-get install -y build-essential
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,071 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Ign:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %%
# !apt-get install -y libegl1-mesa-dev libgles2-mesa-dev libgl1-mesa-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libegl-dev libgl-dev libgles-dev libgles1 libglvnd-core-dev libglvnd-dev libglx-dev libopengl-dev
# The following NEW packages will be installed:
#   libegl-dev libegl1-mesa-dev libgl-dev libgl1-mesa-dev libgles-dev libgles1 libgles2-mesa-dev
#   libglvnd-core-dev libglvnd-dev libglx-dev libopengl-dev
# 0 upgraded, 11 newly installed, 0 to remove and 49 not upgraded.
# Need to get 239 kB of archives.
# After this operation, 2,754 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# ...

# %%
# !python test.py --name=model2009 --epoch=20 --img_folder=./test_images
# Out:
# /usr/local/lib/python3.12/site-packages/kornia/feature/lightglue.py:44: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# ----------------- Options ---------------
#                 add_image: True
#                bfm_folder: BFM
#                 bfm_model: BFM_model_front.mat
#                  camera_d: 10.0
#                    center: 112.0
#           checkpoints_dir: ./checkpoints
#              dataset_mode: None
#                  ddp_port: 12355
#         display_per_batch: True
#                     epoch: 20                            	[default: latest]
#           eval_batch_nums: inf
#                     focal: 1015.0
#                   gpu_ids: 0
#                img_folder: ./test_images                 	[default: examples]
#                 init_path: checkpoints/init_model/resnet50-0676ba61.pth
# ...
